# %% [markdown]
# # Note
# From 2009 - 2018 missing phase 1, 2A(1), 2A(2) applied
#
# (Maybe for this period can use taken numbers instead of applied?)

# %%
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup

YEARS = range(2009, 2026)
BASE = "https://sgschooling.com/year/{year}/all.html"
HEADERS = {
    "User-Agent": "Mozilla/5.0"
}

def cell_value(text: str, kind: str) -> int:
    s = " ".join(text.split())
    if not s or s == "-":
        return 0

    # Prefer a standalone integer (e.g. "52 SC<1 74/52" -> 52)
    m = re.search(r"(?<!/)\b\d+\b(?!/)", s)
    if m:
        return int(m.group())

    # Fallback if cell is only a ratio (e.g. "74/52")
    r = re.search(r"(\d+)\s*/\s*(\d+)", s)
    if r:
        a, t = int(r.group(1)), int(r.group(2))
        return a if kind == "applied" else t

    return 0

def parse_year(year: int):
    url = BASE.format(year=year)
    html = requests.get(url, headers=HEADERS, timeout=40).text
    soup = BeautifulSoup(html, "html.parser")

    rows = soup.select("tr")
    out = []
    current_school = None
    current_applied = None

    for tr in rows:
        cells = tr.find_all(["th", "td"])
        if not cells:
            continue

        texts = [" ".join(c.get_text(" ", strip=True).split()) for c in cells]
        first = texts[0] if texts else ""

        # school row (name row)
        if first and not first.startswith("Ã¢â€ Â³") and first.lower() not in {"school"}:
            # likely school row: first cell has name, others mostly empty
            if any(k in first for k in ["P1 Ballot History", "All Primary Schools"]):
                continue
            if re.search(r"[A-Za-z]", first):
                current_school = first
                current_applied = None
            continue

        # applied row
        if first.startswith("Ã¢â€ Â³ Applied") and current_school:
            vals = [cell_value(x, "applied") for x in texts[1:7]]
            current_applied = sum(vals)
            continue

        # taken row
        if first.startswith("Ã¢â€ Â³ Taken") and current_school:
            vals = [cell_value(x, "taken") for x in texts[1:7]]
            total_taken = sum(vals)
            total_applied = current_applied if current_applied is not None else 0
            out.append({
                "school": current_school,
                "year": year,
                "total_applied": total_applied,
                "total_taken": total_taken,
            })
            current_applied = None

    return out

all_rows = []
for y in YEARS:
    yr = parse_year(y)
    print(y, len(yr))
    all_rows.extend(yr)

df = pd.DataFrame(all_rows, columns=["school", "year", "total_applied", "total_taken"])
df = (
    df.groupby(["school", "year"], as_index=False)[["total_applied", "total_taken"]]
      .max()
      .sort_values(["year", "school"])
      .reset_index(drop=True)
)


print(df.head(20))
print(df.shape)
print(df[["total_applied", "total_taken"]].describe())
# Out:
# 2009 168
# 2010 169
# 2011 170
# 2012 177
# 2013 180
# 2014 180
# 2015 183
# 2016 183
# 2017 184
# 2018 184
# 2019 185
# 2020 186
# 2021 181
# 2022 181
# 2023 181
# 2024 180
# 2025 179
#                      school  year  total_applied  total_taken
# 0                 Admiralty  2009            190          301
# 1             Ahmad Ibrahim  2009             85          146
# 2                   Ai Tong  2009            129          334
# 3              Anchor Green  2009            195          240
# 4                  Anderson  2009            141          240
# 5                Ang Mo Kio  2009            126          207
# 6    Anglo-Chinese (Junior)  2009            136          271
# 7   Anglo-Chinese (Primary)  2009             84          241
# 8                   Angsana  2009             30           61
# 9                    Beacon  2009            205          240
# 10              Bedok Green  2009            113          197
# ...

# %%
# ---- build vacancy df ----
def parse_vacancy_year(year: int):
    url = BASE.format(year=year)
    html = requests.get(url, headers=HEADERS, timeout=40).text
    soup = BeautifulSoup(html, "html.parser")

    out = []
    current_school = None

    for tr in soup.select("tr"):
        cells = tr.find_all(["th", "td"])
        if not cells:
            continue

        texts = [" ".join(c.get_text(" ", strip=True).split()) for c in cells]
        first = texts[0] if texts else ""

        # school row
        if first and not first.startswith("Ã¢â€ Â³") and first.lower() not in {"school"}:
            if any(k in first for k in ["P1 Ballot History", "All Primary Schools"]):
                continue
            if re.search(r"[A-Za-z]", first):
                current_school = first
            continue

        # vacancy row
        if first.startswith("Ã¢â€ Â³ Vacancy") and current_school:
            m = re.search(r"\((\d+)\)", first)
            vacancy = int(m.group(1)) if m else 0
            out.append({
                "school": current_school,
                "year": year,
                "vacancy": vacancy
            })

    return out

vacancy_rows = []
for y in YEARS:
    vacancy_rows.extend(parse_vacancy_year(y))

vacancy_df = pd.DataFrame(vacancy_rows, columns=["school", "year", "vacancy"])
vacancy_df = (
    vacancy_df.groupby(["school", "year"], as_index=False)["vacancy"]
    .max()
)

# ---- merge with your existing df ----
df_merged = df.merge(vacancy_df, on=["school", "year"], how="left")

# optional: fill missing vacancy with 0
df_merged["vacancy"] = df_merged["vacancy"].fillna(0).astype(int)

print(df_merged.head(20))
print(df_merged.shape)
# Out:
#                      school  year  total_applied  total_taken  vacancy
# 0                 Admiralty  2009            190          301      300
# 1             Ahmad Ibrahim  2009             85          146      180
# 2                   Ai Tong  2009            129          334      330
# 3              Anchor Green  2009            195          240      240
# 4                  Anderson  2009            141          240      240
# 5                Ang Mo Kio  2009            126          207      210
# 6    Anglo-Chinese (Junior)  2009            136          271      270
# 7   Anglo-Chinese (Primary)  2009             84          241      240
# 8                   Angsana  2009             30           61      180
# 9                    Beacon  2009            205          240      240
# 10              Bedok Green  2009            113          197      210
# 11                Bendemeer  2009             63          118      150
# ...

# %% [markdown]
# # add indicator if school ballot for that year

# %%
def phase_value(text: str, kind: str) -> int:
    s = " ".join(text.split())
    if not s or s == "-":
        return 0

    # if ratio exists, use it directly
    r = re.search(r"(\d+)\s*/\s*(\d+)", s)
    if r:
        a, t = int(r.group(1)), int(r.group(2))
        return a if kind == "applied" else t

    # otherwise use first standalone integer
    m = re.search(r"\b\d+\b", s)
    return int(m.group()) if m else 0

def parse_ballot_year(year: int):
    url = BASE.format(year=year)
    html = requests.get(url, headers=HEADERS, timeout=40).text
    soup = BeautifulSoup(html, "html.parser")

    out = []
    current_school = None
    applied_vals = None

    for tr in soup.select("tr"):
        cells = tr.find_all(["th", "td"])
        if not cells:
            continue

        texts = [" ".join(c.get_text(' ', strip=True).split()) for c in cells]
        first = texts[0] if texts else ""

        # school row
        if first and not first.startswith("Ã¢â€ Â³") and first.lower() not in {"school"}:
            if any(k in first for k in ["P1 Ballot History", "All Primary Schools"]):
                continue
            if re.search(r"[A-Za-z]", first):
                current_school = first
                applied_vals = None
            continue

        # applied row
        if first.startswith("Ã¢â€ Â³ Applied") and current_school:
            applied_vals = [phase_value(x, "applied") for x in texts[1:7]]
            continue

        # taken row -> decide ballot
        if first.startswith("Ã¢â€ Â³ Taken") and current_school and applied_vals is not None:
            taken_vals = [phase_value(x, "taken") for x in texts[1:7]]
            ballot = int(any(a > t for a, t in zip(applied_vals, taken_vals)))
            out.append({
                "school": current_school,
                "year": year,
                "ballot": ballot
            })
            applied_vals = None

    return out

# build ballot df
ballot_rows = []
for y in YEARS:
    ballot_rows.extend(parse_ballot_year(y))

ballot_df = pd.DataFrame(ballot_rows, columns=["school", "year", "ballot"])
ballot_df = ballot_df.groupby(["school", "year"], as_index=False)["ballot"].max()

# merge into your merged df
df_final = df_merged.merge(ballot_df, on=["school", "year"], how="left")
df_final["ballot"] = df_final["ballot"].fillna(0).astype(int)

df_final.to_csv("../outputs/primary_school_data_2009_2025.csv", index=False)
print(df_final.head(20))
print(df_final.shape)
# Out:
#                      school  year  total_applied  total_taken  vacancy  ballot
# 0                 Admiralty  2009            190          301      300       1
# 1             Ahmad Ibrahim  2009             85          146      180       1
# 2                   Ai Tong  2009            129          334      330       1
# 3              Anchor Green  2009            195          240      240       1
# 4                  Anderson  2009            141          240      240       1
# 5                Ang Mo Kio  2009            126          207      210       0
# 6    Anglo-Chinese (Junior)  2009            136          271      270       1
# 7   Anglo-Chinese (Primary)  2009             84          241      240       1
# 8                   Angsana  2009             30           61      180       0
# 9                    Beacon  2009            205          240      240       1
# 10              Bedok Green  2009            113          197      210       1
# ...

# %% [markdown]
# Lets scrape for only Phase 2B and 2C data from 2009 to 2025, separated by Phases

# %%
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup

YEARS = range(2009, 2026)
BASE = "https://sgschooling.com/year/{year}/all"
HEADERS = {"User-Agent": "Mozilla/5.0"}

def cell_value(text: str, kind: str) -> int:
    s = " ".join(text.split())
    if not s or s == "-":
        return 0

    # Prefer ratio format like "74/52"
    r = re.search(r"(\d+)\s*/\s*(\d+)", s)
    if r:
        a, t = int(r.group(1)), int(r.group(2))
        return a if kind == "applied" else t

    # Fallback to first integer
    m = re.search(r"\b\d+\b", s)
    return int(m.group()) if m else 0

def has_ballot(applied: int, vacancy: int) -> int:
    return int(applied > vacancy)


def normalize_phase_header(text: str) -> str:
    s = re.sub(r"\s+", "", text.lower())
    s = s.replace("phase", "").replace("(", "").replace(")", "")
    if s in {"2b", "p2b"}:
        return "2B"
    if s in {"2c", "p2c"}:
        return "2C"
    return ""

def parse_year_2b_2c(year: int):
    url = BASE.format(year=year)
    html = requests.get(url, headers=HEADERS, timeout=40).text
    soup = BeautifulSoup(html, "html.parser")

    # detect phase column positions from header row
    idx_2b, idx_2c = None, None
    for tr in soup.select("tr"):
        cells = tr.find_all(["th", "td"])
        if not cells:
            continue
        texts = [" ".join(c.get_text(" ", strip=True).split()) for c in cells]
        if texts and texts[0].strip().lower() == "school":
            for i, h in enumerate(texts[1:]):
                key = normalize_phase_header(h)
                if key == "2B" and idx_2b is None:
                    idx_2b = i
                if key == "2C" and idx_2c is None:
                    idx_2c = i
            break

    if idx_2b is None or idx_2c is None:
        raise ValueError(f"Could not find 2B/2C columns for year {year}")

    out = []
    current_school = None
    applied_2b, applied_2c = 0, 0
    vacancy_2b, vacancy_2c = 0, 0
    has_applied = False

    for tr in soup.select("tr"):
        cells = tr.find_all(["th", "td"])
        if not cells:
            continue

        texts = [" ".join(c.get_text(" ", strip=True).split()) for c in cells]
        first = texts[0] if texts else ""
        first_l = first.lower()

        # school row
        if first and "applied" not in first_l and "taken" not in first_l and "vacancy" not in first_l and first_l != "school":
            if any(k in first for k in ["P1 Ballot History", "All Primary Schools"]):
                continue
            if re.search(r"[A-Za-z]", first):
                current_school = first
                has_applied = False
                applied_2b, applied_2c = 0, 0
                vacancy_2b, vacancy_2c = 0, 0
            continue

        # vacancy row
        if "vacancy" in first_l and current_school:
            vals = [cell_value(x, "taken") for x in texts[1:]]
            vacancy_2b = vals[idx_2b] if idx_2b < len(vals) else 0
            vacancy_2c = vals[idx_2c] if idx_2c < len(vals) else 0
            continue

        # applied row
        if "applied" in first_l and current_school:
            vals = [cell_value(x, "applied") for x in texts[1:]]
            applied_2b = vals[idx_2b] if idx_2b < len(vals) else 0
            applied_2c = vals[idx_2c] if idx_2c < len(vals) else 0
            has_applied = True
            continue

        # taken row
        if "taken" in first_l and current_school:
            raw_vals = texts[1:]
            taken_vals = [cell_value(x, "taken") for x in raw_vals]

            taken_2b = taken_vals[idx_2b] if idx_2b < len(taken_vals) else 0
            taken_2c = taken_vals[idx_2c] if idx_2c < len(taken_vals) else 0

            a2b = applied_2b if has_applied else 0
            a2c = applied_2c if has_applied else 0

            out.append({
                "school": current_school,
                "year": year,
                "phase_2b_applied": a2b,
                "phase_2b_taken": taken_2b,
                "phase_2b_vacancy": vacancy_2b,
                "phase_2b_ballot": has_ballot(a2b, vacancy_2b),
                "phase_2c_applied": a2c,
                "phase_2c_taken": taken_2c,
                "phase_2c_vacancy": vacancy_2c,
                "phase_2c_ballot": has_ballot(a2c, vacancy_2c),
            })
            has_applied = False

    return out

rows = []
for y in YEARS:
    yr_rows = parse_year_2b_2c(y)
    print(y, len(yr_rows))
    rows.extend(yr_rows)

df_phase = pd.DataFrame(rows, columns=[
    "school",
    "year",
    "phase_2b_applied",
    "phase_2b_taken",
    "phase_2b_vacancy",
    "phase_2b_ballot",
    "phase_2c_applied",
    "phase_2c_taken",
    "phase_2c_vacancy",
    "phase_2c_ballot",
])

df_phase = (
    df_phase
    .groupby(["school", "year"], as_index=False)[[
        "phase_2b_applied",
        "phase_2b_taken",
        "phase_2b_vacancy",
        "phase_2b_ballot",
        "phase_2c_applied",
        "phase_2c_taken",
        "phase_2c_vacancy",
        "phase_2c_ballot",
    ]]
    .max()
    .sort_values(["year", "school"])
    .reset_index(drop=True)
)

# demand ratios for your formula
# if vacancy is 0, set as NaN to avoid divide-by-zero

df_phase["phase_2b_demand"] = df_phase["phase_2b_applied"] / df_phase["phase_2b_vacancy"].replace(0, pd.NA)
df_phase["phase_2c_demand"] = df_phase["phase_2c_applied"] / df_phase["phase_2c_vacancy"].replace(0, pd.NA)

out_path = "../outputs/phase_2b_2c_2009_2025.csv"
df_phase.to_csv(out_path, index=False)

print(df_phase.head(20))
print(df_phase.shape)
print(f"Saved: {out_path}")

# %% [markdown]
# # Balloting Frequency (School-Level)
# Compute yearly balloting flag from 2B/2C ballot columns, then aggregate to one row per school.

# %%
import pandas as pd

phase_path = "../outputs/phase_2b_2c_2009_2025.csv"
out_path = "../outputs/school_ballot_frequency_2009_2025.csv"

df_phase = pd.read_csv(phase_path)

# A school-year is considered balloted if either phase 2B or phase 2C balloted
df_phase["year_balloted"] = (
    (df_phase["phase_2b_ballot"] == 1) |
    (df_phase["phase_2c_ballot"] == 1)
).astype(int)

# One record per school-year, then aggregate per school
df_year = (
    df_phase.groupby(["school", "year"], as_index=False)["year_balloted"]
    .max()
)

df_freq = (
    df_year.groupby("school", as_index=False)
    .agg(
        total_years_observed=("year", "nunique"),
        years_with_balloting=("year_balloted", "sum")
    )
)

df_freq["ballot_frequency"] = (
    df_freq["years_with_balloting"] / df_freq["total_years_observed"]
)

df_freq = df_freq.sort_values("school").reset_index(drop=True)

df_freq.to_csv(out_path, index=False)

print(df_freq.head(20))
print(df_freq.shape)
print(f"Saved: {out_path}")

# %% [markdown]
# # Weighted School Demand Index
# Combine average Phase 2C demand and school ballot frequency into one weighted score per school.

# %%
import pandas as pd

phase_path = "../outputs/phase_2b_2c_2009_2025.csv"
freq_path = "../outputs/school_ballot_frequency_2009_2025.csv"
out_path = "../outputs/school_demand_index_2009_2025.csv"

# Weights for final index (must sum to 1.0)
W_PHASE2C_DEMAND = 0.7
W_BALLOT_FREQUENCY = 0.3

if abs((W_PHASE2C_DEMAND + W_BALLOT_FREQUENCY) - 1.0) > 1e-9:
    raise ValueError("Weights must sum to 1.0")

df_phase = pd.read_csv(phase_path)
df_freq = pd.read_csv(freq_path)

# 1) Average Phase 2C demand by school (2009-2025)
df_phase["phase_2c_demand"] = pd.to_numeric(df_phase["phase_2c_demand"], errors="coerce")
df_avg = (
    df_phase.groupby("school", as_index=False)["phase_2c_demand"]
    .mean()
    .rename(columns={"phase_2c_demand": "avg_phase2c_demand"})
)

# 2) Merge with school ballot frequency
keep_cols = ["school", "total_years_observed", "years_with_balloting", "ballot_frequency"]
df_idx = df_avg.merge(df_freq[keep_cols], on="school", how="outer")

# Fill metric nulls to keep all schools in output
df_idx["avg_phase2c_demand"] = pd.to_numeric(df_idx["avg_phase2c_demand"], errors="coerce").fillna(0.0)
df_idx["ballot_frequency"] = pd.to_numeric(df_idx["ballot_frequency"], errors="coerce").fillna(0.0)

# Optional outlier control: cap avg demand at 99th percentile
cap_99 = df_idx["avg_phase2c_demand"].quantile(0.99)
df_idx["avg_phase2c_demand_capped"] = df_idx["avg_phase2c_demand"].clip(upper=cap_99)

# Min-max normalize both components to [0, 1]
def min_max_norm(s: pd.Series) -> pd.Series:
    lo, hi = s.min(), s.max()
    if hi == lo:
        return pd.Series([0.0] * len(s), index=s.index)
    return (s - lo) / (hi - lo)

df_idx["avg_phase2c_demand_norm"] = min_max_norm(df_idx["avg_phase2c_demand_capped"])
df_idx["ballot_frequency_norm"] = min_max_norm(df_idx["ballot_frequency"])

# 3) Weighted demand index (0-100)
df_idx["demand_index"] = 100 * (
    W_PHASE2C_DEMAND * df_idx["avg_phase2c_demand_norm"] +
    W_BALLOT_FREQUENCY * df_idx["ballot_frequency_norm"]
)

# Keep output tidy
df_idx = df_idx[[
    "school",
    "total_years_observed",
    "years_with_balloting",
    "ballot_frequency",
    "avg_phase2c_demand",
    "avg_phase2c_demand_capped",
    "avg_phase2c_demand_norm",
    "ballot_frequency_norm",
    "demand_index",
]].sort_values("demand_index", ascending=False).reset_index(drop=True)

df_idx.to_csv(out_path, index=False)

print(df_idx.head(20))
print(df_idx.shape)
print(f"Saved: {out_path}")
